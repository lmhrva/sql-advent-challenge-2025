# %% [markdown]
# # Querying Data for SQL Challenges

# %% [markdown]
# To install:
# 1. pip install pandas
# 2. pip install SQLAlchemy<br>
#     * Check: import sqlalchemy sqlalchemy.__version__
# 3. pip install psycopg

# %%
import pandas as pd

pranks = pd.read_csv("data/grinch_prank_ideas.csv")
pranks.head()
# Out:
#    prank_id       created_at target_name  evilness_score  \
# 0         1   11/1/2024 8:00       Mayor               7
# 1         2  11/3/2024 10:30       Mayor               9
# 2         3  11/5/2024 14:20       Mayor               5
# 3         4   11/2/2024 9:15   Cindy-Lou               3
# 4         5  11/4/2024 11:00   Cindy-Lou               6
#
#                                 prank_description
# 0           Replace his toupee with a bird's nest
# 1                 Steal all his ceremonial sashes
# 2  Fill his office with Christmas carolers at 5am
# 3                       Hide all her hair ribbons
# 4         Replace her hot cocoa with pickle juice
