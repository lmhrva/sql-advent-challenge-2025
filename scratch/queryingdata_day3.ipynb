# %% [markdown]
# # Running RBQL for SQL Challenges

# %% [markdown]
# These installations are taking a ridiculously long time. I need to set up a virtual environment anyway.
#
#
# Here's what I'm trying to install:
# 1. pip install pandas
# 2. pip install SQLAlchemy<br>
#     * Check: import sqlalchemy sqlalchemy.__version__
# 3. pip install psycopg

# %%
import pandas as pd

pranks = pd.read_csv("data/grinch_prank_ideas.csv")
pranks.head()
